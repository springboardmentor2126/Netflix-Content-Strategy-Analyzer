# %%
# Netflix Data Cleaning code

import pandas as pd#Import Libraries
import matplotlib.pyplot as plt
data= pd.read_csv("netflix_titles.csv")#Load the Dataset
data.info()# Initial Data Inspection
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8709 entries, 0 to 8708
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        8709 non-null   str
#  1   type           8709 non-null   str
#  2   title          8709 non-null   str
#  3   director       6168 non-null   str
#  4   cast           7892 non-null   str
#  5   country        7882 non-null   str
#  6   date_added     8709 non-null   str
#  7   release_year   8709 non-null   int64
#  8   rating         8705 non-null   str
#  9   duration       8706 non-null   str
#  10  listed_in      8709 non-null   str
#  11  description    8709 non-null   str
#  12  duration_int   8706 non-null   float64
#  13  duration_type  8706 non-null   str
#  14  year_added     8709 non-null   int64
#  15  month_added    8709 non-null   int64
# dtypes: float64(1), int64(3), str(12)
# memory usage: 1.1 MB

# %%
data.isnull().sum()
data.drop_duplicates(inplace=True)#Remove Duplicate Records
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8704   s8803    Movie                 Zodiac    David Fincher
# 8705   s8804  TV Show            Zombie Dumb              NaN
# 8706   s8805    Movie             Zombieland  Ruben Fleischer
# 8707   s8806    Movie                   Zoom     Peter Hewitt
# 8708   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
print("Duplicates Removed")
# Out:
# Duplicates Removed

# %%
data.dropna(subset=['date_added'], inplace=True)
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8704   s8803    Movie                 Zodiac    David Fincher
# 8705   s8804  TV Show            Zombie Dumb              NaN
# 8706   s8805    Movie             Zombieland  Ruben Fleischer
# 8707   s8806    Movie                   Zoom     Peter Hewitt
# 8708   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data=data.fillna({
    'director':'No data',
    'cast':'No cast',
    'country':'Missing Data',
    'rating':'No Rating'
})

# %%
data['date_added'] = pd.to_datetime(data['date_added'], errors='coerce')
data.dropna(subset=['date_added'], inplace=True)
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          No data
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          No data
# 4         s5  TV Show           Kota Factory          No data
# ...      ...      ...                    ...              ...
# 8704   s8803    Movie                 Zodiac    David Fincher
# 8705   s8804  TV Show            Zombie Dumb          No data
# 8706   s8805    Movie             Zombieland  Ruben Fleischer
# 8707   s8806    Movie                   Zoom     Peter Hewitt
# 8708   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               No cast  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data['year_added']=data['date_added'].dt.year 
data['month_added']=data['date_added'].dt.month
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          No data
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          No data
# 4         s5  TV Show           Kota Factory          No data
# ...      ...      ...                    ...              ...
# 8704   s8803    Movie                 Zodiac    David Fincher
# 8705   s8804  TV Show            Zombie Dumb          No data
# 8706   s8805    Movie             Zombieland  Ruben Fleischer
# 8707   s8806    Movie                   Zoom     Peter Hewitt
# 8708   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               No cast  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
text_cols=['title','director','cast','country','rating','type']
for col in text_cols:
    data[col]=data[col].str.strip()#Clean Text Columns (Remove Extra Spaces)

# %%
data['country'].str.split(',').str[0]#Standardize Country Column
# Out:
# 0       United States
# 1        South Africa
# 2        Missing Data
# 3        Missing Data
# 4               India
#             ...
# 8704    United States
# 8705     Missing Data
# 8706    United States
# 8707    United States
# 8708            India
# Name: country, Length: 8709, dtype: object

# %%
data[['duration_int', 'duration_type']] = data['duration'].str.split(' ', expand=True)
data['duration_int']=pd.to_numeric(data['duration_int'],errors='coerce')
data.dropna(subset=['duration_int'],inplace=True)#Process and Split Duration Column
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          No data
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          No data
# 4         s5  TV Show           Kota Factory          No data
# ...      ...      ...                    ...              ...
# 8704   s8803    Movie                 Zodiac    David Fincher
# 8705   s8804  TV Show            Zombie Dumb          No data
# 8706   s8805    Movie             Zombieland  Ruben Fleischer
# 8707   s8806    Movie                   Zoom     Peter Hewitt
# 8708   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               No cast  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data['content_age']=data['year_added']-data['release_year']
data['release_decade']=(data['release_year']//10)*10 #Feature Engineering
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          No data
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          No data
# 4         s5  TV Show           Kota Factory          No data
# ...      ...      ...                    ...              ...
# 8704   s8803    Movie                 Zodiac    David Fincher
# 8705   s8804  TV Show            Zombie Dumb          No data
# 8706   s8805    Movie             Zombieland  Ruben Fleischer
# 8707   s8806    Movie                   Zoom     Peter Hewitt
# 8708   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               No cast  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
print("Missing Values:",data.isnull().sum())#Final Data Quality Check
# Out:
# Missing Values: show_id           0
# type              0
# title             0
# director          0
# cast              0
# country           0
# date_added        0
# release_year      0
# rating            0
# duration          0
# listed_in         0
# description       0
# duration_int      0
# duration_type     0
# year_added        0
# month_added       0
# content_age       0
# release_decade    0
# dtype: int64

# %%
data.to_csv("netflix_titles_cleaned.csv", index=False)
print("cleaning Completed Successfully")
# Out:
# cleaning Completed Successfully

# %%
 # ================================
# FEATURE ENGINEERING
# ================================
#Create genre_count column
#Splits 'listed_in' by comma and counts number of genres

data['genre_count'] = data['listed_in'].apply(
    lambda x: len([g.strip() for g in x.split(',')])
)

# %%
#Create main_genre column
# Extracts first genre from the list
data['main_genre'] = data['listed_in'].apply(
    lambda x: x.split(',')[0].strip()
)

# %%
#Create main_country column
# Extracts first country if multiple countries exist
data['main_country'] = data['country'].apply(lambda x: x.split(',')[0].strip())

# %%
#Create content_length_category
# Categorizes movies and TV shows based on duration

def categorize_length(row):
    if row['duration_type'] == 'min':
        if row['duration_int'] < 60:
            return "Short Movie"
        elif row['duration_int'] <= 120:
            return "Medium Movie"
        else:
            return "Long Movie"
    else:
        if row['duration_int'] == 1:
            return "Mini Series"
        else:
            return "Multi Season Series"

data['content_length_category'] = data.apply(categorize_length, axis=1)

# %%
#Create content_age_category
# Categorizes content based on how old it is

data['content_age_category'] = pd.cut(
    data['content_age'],
    bins=[-1,2,5,10,50],
    labels=['Very New','New','Moderate','Old']
)

# %%
#Create original_vs_licensed column
# Checks if word "Netflix" exists in title
data['original_vs_licensed'] = data['title'].apply(
    lambda x: "Netflix Original" if "Netflix" in str(x) else "Licensed"
)

# %%
# Print shape after feature engineering
print("Shape After Feature Engineering:", data.shape)
print(data.columns)
# Out:
# Shape After Feature Engineering: (8706, 24)
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'duration_int', 'duration_type', 'year_added', 'month_added',
#        'content_age', 'release_decade', 'genre_count', 'main_genre',
#        'main_country', 'content_length_category', 'content_age_category',
#        'original_vs_licensed'],
#       dtype='str')

# %%
# ================================
# UNIVARIATE ANALYSIS
# ================================
#Cast Count Distribution
plt.figure(figsize=(8,4))
data['cast'].plot(kind='hist', bins=20)
plt.title("Distribution of Cast Count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 6
#       1 # ================================
#       2 # UNIVARIATE ANALYSIS
#       3 # ================================
#       4 #Cast Count Distribution
#       5 plt.figure(figsize=(8,4))
# ----> 6 data['cast'].plot(kind='hist', bins=20)
#       7 plt.title("Distribution of Cast Count")
#       8 plt.show()
#
# File c:\Users\Lenovo\OneDrive\Desktop\MyProject\.venv\Lib\site-packages\pandas\plotting\_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\Lenovo\OneDrive\Desktop\MyProject\.venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
# ...

# %%
#Distribution of content type
plt.figure(figsize=(6,4))
data['type'].value_counts().plot(kind='bar')

plt.title("Distribution of Content Type")
plt.xlabel("Content Type")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# %%
# 2️ Netflix Content Growth Over Time
plt.figure(figsize=(8,4))
data['year_added'].value_counts().sort_index().plot()

plt.title("Netflix Content Growth Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Titles")
plt.show()

# %%
#Release Year Distribution
plt.figure(figsize=(10,4))
data['release_year'].plot(kind='hist', bins=30)
plt.title("Distribution of Release Years")
plt.show()

# %%
#Top 15 Genres
plt.figure(figsize=(10,5))
data['main_genre'].value_counts().head(15).plot(kind='bar')
plt.title("Top 15 Genres")
plt.xticks(rotation=45)
plt.show()

# %%
# ================================
# BIVARIATE ANALYSIS
# ================================

# Movies vs TV Shows Growth Over Years(Trend)
growth = data.groupby(['year_added','type']).size().unstack()

growth.plot(figsize=(8,4))

plt.title("Movies vs TV Shows Growth Over Years")
plt.show()

# %%
# Top 10 Countries by Content
plt.figure(figsize=(8,4))
data['main_country'].value_counts().head(10).plot(kind='bar')

plt.title("Top 10 Countries by Content")
plt.xticks(rotation=45)
plt.show()

# %%
#Type vs Rating
plt.figure(figsize=(10,5))
type_rating = pd.crosstab(data['type'], data['rating'])

type_rating.plot(kind='bar', stacked=True, figsize=(10,5))

plt.title("Type vs Rating")
plt.xticks(rotation=0)
plt.show()

# %%
#Genre Count vs Rating
sns.boxplot(
    data=data,
    x='rating',
    y='genre_count'
)

plt.xticks(rotation=45)
plt.title("Genre Count vs Rating")
plt.show()

# %%
#Genre Count vs Duration(Scatter)
sns.scatterplot(
    data=data[data['type']=='Movie'],
    x='genre_count',
    y='duration_int'
)
plt.show()

# %%
#Correlation Heatmap
import seaborn as sns

plt.figure(figsize=(6,4))
sns.heatmap(
    data[['release_year','year_added','duration_int','genre_count','content_age']].corr(),
    annot=True
)
plt.title("Correlation Matrix")
plt.show()

# %%
data.to_csv("netflix_titles_featured.csv", index=False)

# %%
# =====================================
# MILESTONE 3 - ADVANCED DATA ANALYSIS
# =====================================

import pandas as pd
import matplotlib.pyplot as plt

# Load engineered dataset
data = pd.read_csv("netflix_titles_featured.csv")

# %%
# -----------------------------
# 1. Group titles by Genre, Rating
# -----------------------------

genre_rating = pd.crosstab(data['main_genre'], data['rating'])

top_genres = data['main_genre'].value_counts().head(8).index

genre_rating.loc[top_genres].plot(
    kind='bar',
    stacked=True,
    figsize=(12,6)
)

plt.title("Content Groups by Genre and Rating")
plt.xlabel("Genre")
plt.ylabel("Number of Titles")
plt.show()

# %%
# -----------------------------
# 2. Movies vs TV Shows
# -----------------------------

type_counts = data['type'].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    type_counts.values,
    labels=type_counts.index,
    autopct='%1.1f%%',
    startangle=90
)

plt.title("Movies vs TV Shows Distribution")
plt.show()

# %%
# Content Growth Over Time

year_counts = data['year_added'].value_counts().sort_index()

plt.figure(figsize=(10,5))

plt.plot(year_counts.index, year_counts.values, marker='o')

plt.title("Netflix Content Growth Over Time")
plt.xlabel("Year Added")
plt.ylabel("Number of Titles")

plt.grid(True)

plt.show()

# %%
# -----------------------------
# 3. Duration Comparison
# -----------------------------

movie_data = data[data['type']=="Movie"]
tv_data = data[data['type']=="TV Show"]

plt.figure(figsize=(8,5))

plt.hist(movie_data['duration_int'], bins=30, alpha=0.6, label="Movies")
plt.hist(tv_data['duration_int'], bins=10, alpha=0.6, label="TV Shows")

plt.legend()
plt.title("Duration Comparison: Movies vs TV Shows")
plt.xlabel("Duration")
plt.ylabel("Frequency")
plt.show()

# %%
# -----------------------------
# 4. Country vs Genre Analysis
# -----------------------------

country_genre = pd.crosstab(data['main_country'], data['main_genre'])

top_countries = data['main_country'].value_counts().head(10).index

country_genre.loc[top_countries].plot(
    kind='bar',
    stacked=True,
    figsize=(12,6)
)

plt.title("Country Contribution by Genre")
plt.xlabel("Country")
plt.ylabel("Number of Titles")
plt.show()

# %%
top_countries = data['main_country'].value_counts().head(10)

plt.figure(figsize=(10,6))

plt.barh(top_countries.index, top_countries.values)

plt.title("Top Countries Producing Netflix Content")
plt.xlabel("Number of Titles")
plt.ylabel("Country")

plt.show()

# %%
# -----------------------------
# 5. Feature Relationship Analysis
# -----------------------------

numeric_cols = [
    'release_year',
    'year_added',
    'duration_int',
    'genre_count',
    'content_age'
]

corr = data[numeric_cols].corr()

plt.figure(figsize=(8,6))

plt.imshow(corr)

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.colorbar()
plt.title("Feature Correlation Matrix")

plt.show()


# Save for dashboard
data.to_csv("dashboard_data.csv", index=False)

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("dashboard_data.csv")

st.title("Netflix Content Analysis Dashboard")

# Sidebar filters
year = st.sidebar.slider(
    "Release Year",
    int(data['release_year'].min()),
    int(data['release_year'].max()),
    2015
)

genre = st.sidebar.selectbox(
    "Genre",
    data['main_genre'].unique()
)

filtered = data[
    (data['release_year'] >= year) &
    (data['main_genre'] == genre)
]

st.write("Filtered Data Size:", filtered.shape)


# Genre chart
genre_counts = filtered['main_genre'].value_counts().head(10)

fig, ax = plt.subplots()

ax.bar(genre_counts.index, genre_counts.values)

plt.xticks(rotation=45)

st.pyplot(fig)


# Country chart
country_counts = filtered['main_country'].value_counts().head(10)

fig, ax = plt.subplots()

ax.barh(country_counts.index, country_counts.values)

st.pyplot(fig)


# Content type chart
type_counts = filtered['type'].value_counts()

fig, ax = plt.subplots()

ax.pie(type_counts.values, labels=type_counts.index, autopct='%1.1f%%')

st.pyplot(fig)
# Out:
# 2026-03-12 21:17:13.668 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-12 21:17:14.086
# ...
#   command:
#
#     streamlit run c:\Users\Lenovo\OneDrive\Desktop\MyProject\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-03-12 21:17:14.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-12 21:17:14.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-12 21:17:14.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-12 21:17:14.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-12 21:17:14.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
